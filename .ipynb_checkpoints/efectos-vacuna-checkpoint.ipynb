# %% [markdown]
# # Scraping Twitter Using snscrape
# <br>Package Github: https://github.com/JustAnotherArchivist/snscrape
# <br>This notebook will be using the development version of snscrape
#
# Article Read-Along: https://medium.com/better-programming/how-to-scrape-tweets-with-snscrape-90124ed006af
#
# ### Author: Martin Beck
#
# <b>Dependencies: </b>
# - Your <b>Python</b> version must be <b>3.8</b> or higher. The development version of snscrape will not work with Python 3.7 or lower. You can download the latest Python version [here](https://www.python.org/downloads/).
# - <b>Development version of snscrape</b>, uncomment the pip install line in the below cell to pip install in the notebook if you don't already have it.
# - <b>Pandas</b>, the dataframes allows easy manipulation and indexing of data, this is more of a preference but is what I follow in this notebook.

# %%
#!pip install git+https://github.com/JustAnotherArchivist/snscrape.git

# Imports
import os
import pandas as pd
import itertools
import snscrape.modules.twitter as sntwitter

# %% [markdown]
# # Consulta por búsqueda de texto
# El siguiente código buscará tweets a través de los siguientes términos:
#
# * 'Dolor vacuna'
# * 'efecto vacuna', 'efecto astrazeneca', etc.
# * 'reacción vacuna'
# * 'vacuna #AstraZeneca', 'vacuna #Sputnik', 'vacuna #j&j', etc.
# * sputnik v, moderna
# * 'vacuna sintoma'
# * etc.
#
# La búsqueda será de los años 2020, 2021 y 2022, y que serán almacenados en un archivo CSV

# %%
latitud = '19.309917325231165'   
longitud = '-99.12243737329997'
#radio de distancia a partir de 4
radio = '31.28km' 

localizacion = latitud + ',' + longitud + ',' + radio

#tweet_count = 100

#df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    #'efecto vacuna since:2022-01-01 until:2022-01-31 geocode:"{}"'.format(localizacion)).get_items(),tweet_count))[['id','url','date','content','likeCount','retweetCount']]

df_tw = pd.DataFrame((sntwitter.TwitterSearchScraper(
    'mi vacuna since:2020-12-24 until:2022-09-25 geocode:"{}"'.format(localizacion)).get_items()))[['id','url','date','content','likeCount','retweetCount','replyCount','coordinates','place']]

df_tw['latitud'] = latitud
df_tw['longitud'] = longitud
df_tw['radio'] = radio

df_tw.to_csv('mi_vacuna.csv', sep=',', index=False,mode="w+")

# %%
print(location.address)
# Out:
# Zinacantepec, Estado de México, México

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import time

df = pd.read_csv('dataset.csv')

coord = df['coordinates']

geolocator = Nominatim(user_agent="http")
size = len(coord)
locations = []
reverse = RateLimiter(geolocator.reverse, min_delay_seconds=1)


for i in range(size):
    if type(coord[i]) is str:
        dicc = eval(coord[i])
        lat = dicc['latitude']
        long = dicc['longitude']
    
        location = str(lat) + ', ' + str(long)  
        locations.append(reverse((location), language='es', exactly_one=True))
    #locations.append(geolocator.reverse()[0]) 
    #time.sleep(2)

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from functools import partial
import time

df = pd.read_csv('posibles_efectos_6.csv')

lon = df['lon']
lat = df['lat']

geolocator = Nominatim(user_agent="http")
geocode = partial(geolocator.geocode, language="es")
size = len(lon)
print(size)
locations = []
reverse = partial(geolocator.reverse, language="es")


for i in range(size):    
    location = str(lat[i]) + ', ' + str(lon[i])  
    locations.append(reverse((location)))
# Out:
# 745

# %%
dicc_alcaldias = {'Azcapotzalco' : 0, 'Coyoacán' : 0, 'Cuajimalpa de Morelos' : 0, 'Gustavo A. Madero' : 0,
                  'Iztacalco' : 0, 'Iztapalapa' : 0, 'La Magdalena Contreras' : 0, 'Milpa Alta' : 0,
                  'Álvaro Obregón' : 0, 'Tláhuac': 0, 'Tlalpan' : 0, 'Xochimilco' : 0, 'Benito Juárez' : 0,
                  'Cuauhtémoc' : 0, 'Miguel Hidalgo' : 0, 'Venustiano Carranza' : 0}

long = []
lat = []
e = []

for i in range(len(locations)):
    for alcaldia in dicc_alcaldias.keys():
        if alcaldia in str(locations[i]):
            #dicc_alcaldias[alcaldia] += 1 
            long.append(df['lon'][i])
            lat.append(df['lat'][i])
            e.append(df['0'][i])

df2 = pd.DataFrame(e, columns=['tweet'])
df2['lon'] = long
df2['lat'] = lat
print(df.head())
# Out:
#    Unnamed: 0  Dominant_Topic  Perc_Contribution  \
# 0          13             6.0             0.2955
# 1          14             6.0             0.3556
# 2          31             6.0             0.4598
# 3          43             6.0             0.5500
# 4          50             6.0             0.6698
#
#                                       Topic_Keywords  \
# 0  moderna, post, cansancio, fila, bonito, minuto...
# 1  moderna, post, cansancio, fila, bonito, minuto...
# 2  moderna, post, cansancio, fila, bonito, minuto...
# 3  moderna, post, cansancio, fila, bonito, minuto...
# 4  moderna, post, cansancio, fila, bonito, minuto...
#
#                                                    0        lat        lon
# 0  ['mano', 'janssen', 'curiosamente', 'ma', 'fre...  19.444937 -99.180678
# 1      ['maldito', 'vacuna', 'ando', 'rojo', 'cara']  19.285882 -98.954037
# 2  ['noche', 'salchiamigo', 'marcha', 'candi', 'j...  19.087511 -99.315748
# 3  ['manden', 'vibras', 'bonita', 'vacuna', 'lema...  19.221883 -99.572009
# 4  ['fila', 'persona', 'sentadas', 'brazo', 'desc...  19.309899 -99.177192

# %%
df2.to_csv('ds_pe6.csv')

# %%
print(dicc_alcaldias)
# Out:
# {'Azcapotzalco': 0, 'Coyoacán': 0, 'Cuajimalpa de Morelos': 4, 'Gustavo A. Madero': 5, 'Iztacalco': 1, 'Iztapalapa': 3, 'La Magdalena Contreras': 0, 'Milpa Alta': 2, 'Álvaro Obregón': 11, 'Tláhuac': 0, 'Tlalpan': 10, 'Xochimilco': 0, 'Benito Juárez': 1, 'Cuauhtémoc': 3, 'Miguel Hidalgo': 23, 'Venustiano Carranza': 0}

# %% [markdown]
# # Pre-procesamiento

# %%
import re
#!pip install emoji
import emoji
import pandas as pd
import numpy as np
#!pip install unidecode
from unidecode import unidecode

import nltk 
from nltk.tokenize import TweetTokenizer
#nltk.download('stopwords')
from nltk.corpus import stopwords

#!pip install pyspellchecker
from spellchecker import SpellChecker

from nltk.stem import WordNetLemmatizer
#nltk.download('wordnet')
#nltk.download('omw')
from nltk.corpus import wordnet

#!pip install spacy
import spacy
#!python -m spacy download es
#nlp = spacy.load('es_core_news_sm')

#!pip install stanza
import stanza
nlp = stanza.Pipeline('es',processors='tokenize,mwt,lemma')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.0.json:   0%|   …
# 2022-12-14 21:35:35 INFO: Loading these models for language: es (Spanish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# | lemma     | ancora  |
# =======================
#
# 2022-12-14 21:35:35 INFO: Use device: cpu
# 2022-12-14 21:35:35 INFO: Loading: tokenize
# 2022-12-14 21:35:35 INFO: Loading: mwt
# 2022-12-14 21:35:35 INFO: Loading: lemma
# 2022-12-14 21:35:36 INFO: Done loading processors!

# %%
nombre_archivo = "fiebre_vacuna.csv"

df_tw = pd.read_csv(nombre_archivo)
df_tw.head()
# Out:
#              id                                                url  \
# 0  1.500000e+18  https://twitter.com/mr_mazaa/status/1501536964...
# 1  1.490000e+18  https://twitter.com/J2ACVDOMER/status/14935977...
# 2  1.490000e+18  https://twitter.com/verushhk/status/1489253732...
# 3  1.480000e+18  https://twitter.com/iris_charo/status/14840485...
# 4  1.460000e+18  https://twitter.com/MichellMor/status/14644676...
#
#                         date  \
# 0  2022-03-09 12:34:44+00:00
# 1  2022-02-15 14:46:57+00:00
# 2  2022-02-03 15:05:33+00:00
# 3  2022-01-20 06:22:12+00:00
# 4  2021-11-27 05:34:28+00:00
#
#                                              content  likeCount  retweetCount  \
# 0  Si está muuuy dura la vacuna, dolor de brazo, ...          1             0
# 1  Ya saliendo de la reacción de la vacuna 💉 solo...          0             0
# 2  Vengo de la oscuridad a decir que sobreviví a ...          5             0
# 3  Acabo de soñar que tenía chingos de fiebre por...          4             0
# 4  Con la vacuna del COVID-19 no me dolió el braz...          2             0
#
#    replyCount                                        coordinates  \
# 0           1  {'longitude': -99.7825792, 'latitude': 19.0763...
# 1           0  {'longitude': -99.1843501, 'latitude': 19.3998...
# 2           2   {'longitude': -99.180678, 'latitude': 19.444937}
# 3           0   {'longitude': -99.118665, 'latitude': 19.484399}
# 4           0  {'longitude': -99.1600234, 'latitude': 19.152878}
#
#                                                place    latitud   longitud  \
# 0  {'fullName': 'Toluca, México', 'name': 'Toluca...  19.309917 -99.122437
# 1  {'fullName': 'Cuauhtémoc, Distrito Federal', '...  19.309917 -99.122437
# 2  {'fullName': 'Gustavo A. Madero, Distrito Fede...  19.309917 -99.122437
# 3  {'fullName': 'Ecatepec de Morelos, México', 'n...  19.309917 -99.122437
# 4  {'fullName': 'Xochimilco, Distrito Federal', '...  19.309917 -99.122437
#
#      radio                                   tweet_tokenizado  palabra_clave
# 0  31.28km  ['duro', 'vacuna', 'dolor brazo', 'fiebre', 'c...  fiebre vacuna
# 1  31.28km  ['salir', 'reaccion', 'vacuna', 'quedar', 'sue...  fiebre vacuna
# 2  31.28km  ['vengo', 'oscuridad', 'sobrevivi', 'noche', '...  fiebre vacuna
# 3  31.28km  ['acabar', 'sonar', 'chino', 'fiebre', 'vacuna...  fiebre vacuna
# 4  31.28km  ['vacuna', 'covid', 'dolio', 'brazo', 'fiebre'...  fiebre vacuna

# %%
def remover_links(tweet):
    tweet = re.sub(r'http\S+', '', tweet)   # quitar http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet)  # quitar bitly links
    tweet = tweet.strip('[link]')   # quitar [links]
    
    return tweet

def remover_menciones(tweet):
    tweet = re.sub(r"@\S+", "", tweet)
    
    return tweet

def rep(m):
    s = m.group(1)
    return ' '.join(re.split(r'(?=[A-Z])', s))

def separar_palabras_hashtag(tweet):
    tweet = re.sub(r'#(\w+)', rep, tweet)
    
    return tweet

def separar_numeros_de_letras(tweet):
    tweet = re.findall(r'\D+|\d+', tweet)
    
    return lista_a_cadena(tweet)
    
def remover_hashtag(tweet):  
    tweet = re.sub(r'#', '', tweet)
    
    return tweet

def arreglar_abreviaciones(tweet):
    palabras = tweet.split()

    abreviaciones = {'d': 'de',
               'x': 'por',
               'xa': 'para',
               'as': 'has',
               'q': 'que',
               'k': 'que',
               'dl': 'del',
               'xq': 'porqué',
               'dr': 'doctor',
               'dra': 'doctora',
               'sr': 'señor',
               'sra': 'señora',
                'srta':'señorita',
               'm': 'me',
               'aprox': 'aproximadamente',
               'hrs': 'horas',
                '1er': 'primer',
                '1era': 'primera',
                '1ra' : 'primera',
                '1ra': 'primera',
                '2do': 'segundo',
                '2da': 'segunda',
                '3er': 'tercer',
                '3ero': 'tercero',
                '3era': 'tercera',
                '3ra' : 'tercera',
                'jj': 'johnson',
                'amixs': 'amigos',
                'pos': 'pues',
                'ok': 'está bien',
                'lit': 'literal',
                'vs': 'contra',
                'ptm': 'puta madre',
                'alch': 'al chile',
                'desminulleron' : 'disminuyeron',
                'días': 'día',
                'kg': 'kilogramo',
                'mg': 'miligramo',
                'echo' : 'hecho',
                'mins' : 'minutos',
                'min' : 'minuto',
                'pa': 'para',
                'holi' : 'hola',
                'am' : 'antes del mediodia',
                'pm' : 'despues del mediodia',
                'desminulleron' : 'disminuyeron',
                'vrsh' : 'vete al diablo',
                'chxngxdx' : 'chingados'}
    
        
    tweet = " ".join([abreviaciones[palabra] if palabra in abreviaciones.keys() else palabra for palabra in palabras])

    return tweet

def generar_bigramas(tweet_tokenizado):
    i = 0
    
    tamañio = len(tweet_tokenizado)
    palabras = tweet_tokenizado
    
    for palabra in palabras:
        if palabra == 'dolor':
            if not (i + 1 == tamañio):
               
                if palabras[i + 1] == 'pierna':
                    palabras[i] = 'dolor pierna'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'brazo':
                    
                    palabras[i] = 'dolor brazo'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'cabeza':
                    palabras[i] = 'dolor cabeza'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'muscular':
                    palabras[i] = 'dolor muscular'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'articular':
                    palabras[i] = 'dolor articular'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'cuerpo':
                    palabras[i] = 'dolor cuerpo'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'garganta':
                    palabras[i] = 'dolor garganta'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                    
        if palabra == 'dificultad':
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'respirar':
                    palabras[i] = 'dificultad respirar'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                    
        if palabra == 'cuerpo':
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'cortado':
                    palabras[i] = 'cuerpo cortado'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                    
        if palabra == 'irritacion':
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'brazo':
                    palabras[i] = 'irritacion brazo'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1] 
        
        if palabra == 'inflamacion':
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'brazo':
                    palabras[i] = 'inflamacion brazo'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
        
        if palabra == 'hinchazon':
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'brazo':
                    palabras[i] = 'hinchazon brazo'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                        
        i += 1
        
    return palabras

def arreglar_nombres_vacunas(tweet):
    i = 0
    
    palabras = tweet.split()
    
    tamañio = len(palabras)
    
    for palabra in palabras:
        #normaliza el nombre de la vacuna inglesa
        if palabra == 'astra':
            palabras[i] = 'astrazeneca'
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'zeneca':
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                    
                elif palabras[i + 1] == 'seneca':
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                    
        elif palabra == 'aztra':
            palabras[i] = 'astrazeneca'
            
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'zeneca':
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'seneca':
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                    
        elif palabra == 'zeneca':
            palabras[i] = 'astrazeneca'
        
        elif palabra == 'aztrazeneca':
            palabras[i] = 'astrazeneca'
            
        elif palabra == 'astrazeneca':
            palabras[i] = 'astrazeneca'
            
        elif palabra == 'aztraceneca':
            palabras[i] = 'astrazeneca'
            
        elif palabra == 'astraseneca':
            palabras[i] = 'astrazeneca'
            
        i+=1
    
    return lista_a_cadena(palabras)
    
def remover_estilos(tweet):  
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    
    return tweet

def remover_numeros(tweet):
    tweet = re.sub(r'[0-9]', '', tweet)
    
    return tweet

def minusculas(tweet):
    tweet = tweet.lower()
    
    return tweet

def remover_puntuaciones(tweet):
    puntuaciones = '!"$%&\'()*+,-./:;<=>¿?[\\]^_`{|}~•@º'
    tweet = re.sub('[' + puntuaciones + ']+', '', tweet) 
    
    #Remover comillas
    tweet = tweet.replace("’", "")
    tweet = tweet.replace("“", '')
    tweet = tweet.replace("”", '')
    
    #Remover puntos de suspensión
    tweet = tweet.replace('\u2026', '')
    
    return tweet

def remover_espacios(tweet):
    tweet = re.sub('\s+', ' ', tweet)
    
    return tweet

def remover_emojis(tweet):
    tweet = emoji.replace_emoji(tweet, replace='')
    #tweet = re.sub(emoji.get_emoji_regexp(), r"", tweet)
    
    return tweet

def remover_letras_repetidas(tweet):
    tweet = re.sub(r'(.)\1{2,}',r'\1', tweet)
    
    return tweet

def remover_signos_diacríticos(tweet):
    #Conversión de la letra ñ a n
    tweet = re.sub(u"[ñ]", 'n', tweet)
    
    #Remover signos diacríticos
    tweet = unidecode(tweet)
    
    return tweet

def tokenizar(tweet):
    tk = TweetTokenizer()
    tweet_tokenizado = tk.tokenize(tweet) 
    
    return tweet_tokenizado

def remover_stopwords(tweet_tokenizado):   
    with open('stopwords.txt', encoding='utf-8') as f:
        palabras_auxiliares = f.read().splitlines()
        
    stop_words = stopwords.words('spanish')
    
    for palabra in palabras_auxiliares:
        stop_words.append(palabra)
        
    tweet_tokenizado = [palabra for palabra in tweet_tokenizado if palabra not in stop_words]
    
    return lista_a_cadena(tweet_tokenizado)

def remover_único_token(tweet): 
    tweet_tokenizado = tokenizar(tweet)
    
    for palabra in tweet_tokenizado:
        if len(palabra) == 1 :
            tweet_tokenizado.remove(palabra)
            
    return tweet_tokenizado

def corrector_otográfico(tweet):
    spell = SpellChecker(language='es')
    
    #Agrega nuevos términos al corrector ortográfico
    spell.word_frequency.load_text_file('terminos.txt')

    spell.word_frequency.load_words(['covid','sputnik', 'astrazeneca','pfizer','biontech','pfizerbiontech',
                                    'cansino','moderna','janssen','johnson','booster','imss','gatell','gatel','sars',
                                     'cov','gripita', 'sarscov'])
        
    k = 0
    
    for palabra in tweet:
        palabra_correcta = spell.correction(palabra)
        tweet[k] = palabra_correcta
        
        k+=1 
        
    return lista_a_cadena(tweet)

def lista_a_cadena(s):
    str1 = " "
   
    return (str1.join(s))

def lematizar(tweet_tokenizado):
    doc = nlp(tweet_tokenizado)
            
    lista = []

    for oracion in doc.sentences:
        for palabra in oracion.words:
            if palabra.text == 'gatell':
                lista.append('gatell')
            elif palabra.text == 'sars':
                lista.append('sars')
            elif palabra.text == 'coronavirus':
                lista.append('coronavirus')    
            elif palabra.text == 'tos':
                lista.append('tos')
            elif palabra.text == 'moderna':
                lista.append('moderna')
            elif palabra.text == 'vacunación':
                lista.append('vacuna')
            elif palabra.text == 'vacunacion':
                lista.append('vacuna')
            elif palabra.text == 'vacunar':
                lista.append('vacuna')
            elif palabra.text == 'vacunado':
                lista.append('vacuna')
            elif palabra.text == 'vacunados':
                lista.append('vacuna')
            elif palabra.text == 'vacunen':
                lista.append('vacuna')
            elif palabra.text == 'vacunaron':
                lista.append('vacuna')
            elif palabra.text == 'vacuno':
                lista.append('vacuna')
            elif palabra.text == 'vacunamos':
                lista.append('vacuna')
            elif palabra.text == 'vacuné':
                lista.append('vacuna')
            elif palabra.text == 'vacune':
                lista.append('vacuna')
            elif palabra.text == 'vacunan':
                lista.append('vacuna')
            elif palabra.text == 'vacunó':
                lista.append('vacuna')
            elif palabra.text == 'vacunaron':
                lista.append('vacuna')
            elif palabra.text == 'vacunaste':
                lista.append('vacuna')    
            else:
                lema = palabra.lemma
                
                if not (lema == 'él' or lema == 'yo'):
                    lista.append(lema)

    return lista

# %%
content = df_tw['content']
lista_tokens = []

for i in range(len(content)):
    tweet = content[i]
    tweet = remover_links(tweet)
    tweet = remover_menciones(tweet)
    tweet = remover_estilos(tweet)
    tweet = separar_palabras_hashtag(tweet)
    tweet = minusculas(tweet)
    tweet = remover_puntuaciones(tweet)
    tweet = remover_espacios(tweet)
    tweet = remover_emojis(tweet)
    tweet = remover_letras_repetidas(tweet)
    tweet = arreglar_abreviaciones(tweet)
    tweet = separar_numeros_de_letras(tweet)
    tweet = remover_numeros(tweet)
    tweet = arreglar_abreviaciones(tweet)
    tweet = arreglar_nombres_vacunas(tweet)
    tweet_tokenizado = tokenizar(tweet)
    tweet_tokenizado = corrector_otográfico(tweet_tokenizado)
    tweet_tokenizado = lematizar(tweet_tokenizado)
    tweet_tokenizado = remover_stopwords(tweet_tokenizado)
    tweet_tokenizado = remover_signos_diacríticos(tweet_tokenizado)
    tweet_tokenizado = generar_bigramas(tweet_tokenizado)
    tweet_tokenizado = remover_único_token(tweet_tokenizado) 
    
    lista_tokens.append(tweet_tokenizado)

# %%
l = ["Tercerda dosis de #AstraZeneca ayer. La primera escalofríos, dolor muscular, articular, no tan mal. La segunda algo de cansancio. La tercera limpia (al menos 24 horas después). 🙃",
    "Dos días de que me pusieron mi segunda dosis de vacuna #AstraZeneca y vuelvo a despertar con dolor de cabeza 😩😩😩"]

lista_tokens = []

for i in range(len(l)):
    tweet = l[i]
    tweet = remover_links(tweet)
    tweet = remover_menciones(tweet)
    tweet = remover_estilos(tweet)
    tweet = separar_palabras_hashtag(tweet)
    tweet = minusculas(tweet)
    tweet = remover_puntuaciones(tweet)
    tweet = remover_espacios(tweet)
    tweet = remover_emojis(tweet)
    tweet = remover_letras_repetidas(tweet)
    tweet = arreglar_abreviaciones(tweet)
    tweet = separar_numeros_de_letras(tweet)
    tweet = remover_numeros(tweet)
    tweet = arreglar_abreviaciones(tweet)
    tweet = arreglar_nombres_vacunas(tweet)
    tweet_tokenizado = tokenizar(tweet)
    tweet_tokenizado = corrector_otográfico(tweet_tokenizado)
    tweet_tokenizado = lematizar(tweet_tokenizado) 
    tweet_tokenizado = remover_stopwords(tweet_tokenizado)
    tweet_tokenizado = remover_signos_diacríticos(tweet_tokenizado)
    tweet_tokenizado = remover_único_token(tweet_tokenizado)
    
    lista_tokens.append(tweet_tokenizado)
    
print(lista_tokens)
# Out:
# [['tercero', 'dosis', 'astrazeneca', 'escalofrio', 'dolor', 'muscular', 'articular', 'cansancio', 'tercero', 'limpio', 'hora'], ['dosis', 'vacuna', 'astrazeneca', 'volver', 'despertar', 'dolor', 'cabeza']]

# %%
termino = " ".join(nombre_archivo.split(".")[0].split("_"))
df_tw['palabra_clave'] = termino

df_tw['tweet_tokenizado'] = lista_tokens

df_tw.to_csv(nombre_archivo, sep=',', index=False,mode="w+")

# %% [markdown]
# # Separación de fecha

# %% [markdown]
# # Carga del dataset

# %%
import pandas as pd
import regex as re

df_tw = pd.read_csv("dataset_sin_duplicados.csv", encoding = "ISO-8859-1")
df_tw.head()
# Out:
#              id                                                url  \
# 0  1.530000e+18  https://twitter.com/el_dui/status/152911694041...
# 1  1.530000e+18  https://twitter.com/el_dui/status/152894687205...
# 2  1.500000e+18  https://twitter.com/pharmanewsmx/status/150025...
# 3  1.500000e+18  https://twitter.com/IvisAburto/status/14992290...
# 4  1.490000e+18  https://twitter.com/Rienlog/status/14915689126...
#
#                         date  \
# 0  2022-05-24 15:07:42+00:00
# 1  2022-05-24 03:51:55+00:00
# 2  2022-03-05 23:29:09+00:00
# 3  2022-03-03 03:43:50+00:00
# 4  2022-02-10 00:25:15+00:00
#
#                                              content  likeCount  retweetCount  \
# 0  @abrahamendieta @LaydaSansores Como va, @alito...          3             0
# 1  AsÃÂ­ como va, @alitomorenoc podrÃÂ­a public...          0             0
# 2  Pongamosle fin al estigma de la obesidad by Et...          1             0
# 3  Probablemente no hubiera sido gol, pero lo que...          1             0
# 4          @HectorRossete Si J&amp;J + booster shoot          0             0
#
#    replyCount                                        coordinates  \
# 0           0  {'longitude': -99.140238, 'latitude': 19.2846922}
# 1           0  {'longitude': -99.140238, 'latitude': 19.2846922}
# 2           0   {'longitude': -99.364536, 'latitude': 19.049016}
# 3           0   {'longitude': -99.315748, 'latitude': 19.087511}
# 4           0   {'longitude': -99.221136, 'latitude': 19.456367}
#
#                                                place    latitud   longitud  \
# 0  {'fullName': 'Iztapalapa, Distrito Federal', '...  19.309917 -99.122437
# 1  {'fullName': 'Iztapalapa, Distrito Federal', '...  19.309917 -99.122437
# 2  {'fullName': 'Distrito Federal, MÃÂ©xico', 'n...  19.309917 -99.122437
# 3  {'fullName': 'Tlalpan, Distrito Federal', 'nam...  19.309917 -99.122437
# 4  {'fullName': 'Azcapotzalco, Distrito Federal',...  19.309917 -99.122437
#
#      radio                                   tweet_tokenizado palabra_clave
# 0  31.28km  ['recopilar', ' audio', ' libro', ' tamano', '...          #j j
# 1  31.28km  ['publicar', ' audio', ' libro', ' tamano', ' ...          #j j
# 2  31.28km  ['pongamosle', ' estigma', ' obesidad', ' by',...          #j j
# 3  31.28km  ['probablemente', ' gol', ' hacias', ' chiva',...          #j j
# 4  31.28km                    ['campo', ' booster', ' shoot']          #j j

# %%
import numpy as np

tokens = df_tw['tweet_tokenizado']

puntuaciones = "]'["
lista_tokens = []
tokens_vacios = []

from nltk.corpus import stopwords

def remover_stopwords(tweet_tokenizado):   
    with open('stopwords.txt', encoding='utf-8') as f:
        palabras_auxiliares = f.read().splitlines()
        
    stop_words = stopwords.words('spanish')
    
    for palabra in palabras_auxiliares:
        stop_words.append(palabra)
    
    lista = []
    
    for palabras in tweet_tokenizado:
        lpalabras = []
        for palabra in palabras:
            if palabra not in stop_words:
                lpalabras.append(palabra)
        lista.append(lpalabras)
    tweet_tokenizado = lista#[palabra for palabra in tweet_tokenizado if palabra not in stop_words]
    
    return tweet_tokenizado

lista_documentos = []

for token in tokens:
    token = re.sub('[' + puntuaciones + ']+', '', token)
    token = re.split(r'[,]+', token)
    lista_documentos.append(token)
    
list_doc = remover_stopwords(lista_documentos)

vocabulario = {}
i = 0
j = 0
for token in list_doc:
    for t in token:
        j += 1
        if t.strip() not in vocabulario:
            vocabulario[t.strip()] = 0
            i += 1
        else:
            vocabulario[t.strip()] += 1

sv = dict(sorted(vocabulario.items(), key=lambda item:item[1], reverse=True))
print(j)
l = list(sv.values())

sum = 0
for v in l:
    sum += v
    
#print(sum)
print(sv)
# Out:
# 590708
# {'vacuna': 60220, 'dosis': 11341, 'covid': 5760, 'ano': 4943, 'mexico': 4649, 'gobierno': 3368, 'salud': 2895, 'persona': 2648, 'gracias': 2639, 'sputnik': 2401, 'esperar': 2298, 'nino': 2263, 'aplicar': 2212, 'pais': 2184, 'astrazeneca': 2147, 'poner': 2145, 'mayor': 2094, 'medico': 2091, 'llegar': 2074, 'pandemia': 2008, 'millon': 1997, 'adulto': 1982, 'seguir': 1962, 'tocar': 1931, 'gente': 1926, 'querer': 1922, 'recibir': 1807, 'pfizer': 1801, 'semana': 1648, 'pasar': 1609, 'ver': 1547, 'mexicano': 1530, 'personal': 1501, 'comprar': 1455, 'deber': 1454, 'cansancio': 1400, 'presidente': 1343, 'mil': 1290, 'malo': 1286, 'refuerzo': 1285, 'poder': 1253, 'menor': 1251, 'moderna': 1246, 'mes': 1241, 'poblacion': 1217, 'decir': 1213, 'salir': 1169, 'dejar': 1168, 'aplicacion': 1148, 'dar': 1147, 'tu': 1097, 'vida': 1061, 'clase': 1054, 'falta': 1043, 'edad': 1039, 'hacer': 1038, 'ir': 1008, 'sentir': 955, 'alcaldia': 940, 'mundo': 928, 'centro': 926, 'morena': 926, 'doctor': 911, 'como': 901, 'caso': 886, 'contagio': 886, 'pedir': 866, 'favor': 863, 'dinero': 855, 'nacional': 845, 'muerte': 844, 'pensar': 830, 'necesitar': 821, 'privado': 803, 'informacion': 800, 'seguro': 797, 'manana': 787, 'hospital': 785, 'madre': 770, 'creer': 767, 'lopez': 766, 'pagar': 762, 'dome': 749, 'plan': 743, 'ciudad': 742, 'quedar': 739, 'cubrebocas': 739, 'mama': 737, 'fecha': 737, 'casa': 737, 'voto': 736, 'federal': 723, 'problema': 715, 'campana': 704, 'fila': 691, 'prueba': 687, 'medicamento': 687, 'ruso': 684, 'unico': 684, 'empezar': 681, 'cansino': 678, 'efecto': 673, 'importante': 671, 'acabar': 671, 'sede': 665, 'morir': 664, 'familia': 659, 'hijo': 654, 'entender': 650, 'regresar': 649, 'enfermedad': 648, 'llevar': 647, 'derecho': 640, 'venir': 633, 'senor': 633, 'maestro': 630, 'sector': 629, 'joven': 626, 'alguien': 622, 'publico': 621, 'atencion': 619, 'acudir': 612, 'iniciar': 612, 'registro': 608, 'riesgo': 601, 'pueblo': 599, 'completo': 595, 'estrategia': 588, 'hablar': 585, 'certificado': 585, 'esquema': 576, 'amigo': 573, 'pinche': 568, 'aplicado': 567, 'hola': 558, 'cumplir': 557, 'feliz': 556, 'terminar': 555, 'padre': 554, 'excelente': 549, 'vivir': 545, 'servir': 541, 'ojala': 536, 'mentira': 531, 'pendejo': 529, 'virus': 528, 'fase': 523, 'regreso': 520, 'muerto': 517, 'dato': 513, 'programa': 513, 'robar': 499, 'pregunta': 499, 'perder': 497, 'saludo': 497, 'via': 494, 'respuesta': 490, 'tema': 488, 'compra': 488, 'in': 482, 'noticia': 476, 'sistema': 471, 'medicina': 470, 'reaccion': 467, 'positivo': 461, 'aplicando': 461, 'andar': 455, 'importar': 452, 'cancer': 448, 'faltar': 446, 'medida': 445, 'jornada': 441, 'evitar': 439, 'duda': 436, 'electoral': 434, 'escuela': 433, 'lamentablemente': 431, 'registrar': 429, 'rezagados': 428, 'volver': 428, 'politico': 428, 'necesario': 428, 'pobre': 423, 'papa': 422, 'buscar': 421, 'historia': 420, 'organizacion': 418, 'hora': 417, 'social': 414, 'unido': 413, 'punto': 412, 'sintoma': 412, 'papas': 412, 'alto': 411, 'rapido': 410, 'municipio': 407, 'dios': 406, 'grupo': 405, 'llamar': 405, 'jajaja': 404, 'forma': 404, 'cuidar': 396, 'cuidando': 396, 'proceso': 394, 'recordar': 391, 'de': 389, 'ayudar': 388, 'informar': 385, 'suficiente': 380, 'influenza': 377, 'negar': 376, 'traer': 371, 'valer': 370, 'preguntar': 370, 'linea': 369, 'impuesto': 368, 'numero': 367, 'tlalnepantla': 366, 'eleccion': 366, 'razon': 365, 'listo': 363, 'pagina': 362, 'chimalhuacan': 360, 'miedo': 359, 'paciente': 359, 'agua': 359, 'nacion': 358, 'mundial': 356, 'felicidad': 356, 'vender': 355, 'foto': 353, 'nivel': 350, 'urge': 350, 'mediodia': 349, 'tomar': 349, 'noche': 347, 'entrar': 345, 'leer': 345, 'secretaria': 345, 'mujer': 343, 'chino': 343, 'super': 339, 'escribir': 337, 'apoyo': 335, 'tipo': 334, 'enfermera': 334, 'presencial': 333, 'atender': 332, 'mano': 331, 'seguridad': 330, 'paso': 329, 'minuto': 328, 'vacunada': 328, 'mayoria': 326, 'funcionar': 325, 'ciudadano': 324, 'palacio': 323, 'a ...

# %% [markdown]
# # Eliminación de tweets duplicados

# %%
tokens = df_tw['tweet_tokenizado']

puntuaciones = "]'["
lista_tokens = []
tokens_vacios = []

i = 0

for token in tokens:
    token = re.sub('[' + puntuaciones + ']+', '', token)
    token = re.split(r'[,]+', token)

    if len(token) <= 1:
        tokens_vacios.append(i)
    else:
        lista_tokens.append(token)
        
    i += 1

df_tw = df_tw.drop(df_tw.index[tokens_vacios])
df_tw['tweet_tokenizado'] = lista_tokens
        

df = df_tw.drop_duplicates(subset = ['content'], keep = 'last')

print(df.count())
# Out:
# id                  60734
# url                 60734
# date                60734
# content             60734
# likeCount           60734
# retweetCount        60734
# replyCount          60734
# coordinates         60733
# place               60734
# latitud             60734
# longitud            60734
# radio               60734
# tweet_tokenizado    60734
# palabra_clave       60734
# dtype: int64

# %% [markdown]
# # Partición del dataset

# %%
from sklearn.model_selection import train_test_split

entrenamiento, prueba = train_test_split(df, test_size=0.2)

# %%
entrenamiento.to_csv('entrenamiento.csv',sep=',', index=False,mode="w+")
prueba.to_csv('prueba.csv',sep=',', index=False,mode="w+")

# %% [markdown]
# # Lectura de los datos de entrenamiento para el modelo de aprendizaje (Doc2Vec y K-Means)

# %%
import regex as re
import pandas as pd

entrenamiento = pd.read_csv("entrenamiento.csv", encoding = "ISO-8859-1")
print(len(entrenamiento))

tokens = entrenamiento['tweet_tokenizado']

puntuaciones = "]'["
lista_tokens = []
tokens_vacios = []

i = 0

for token in tokens:
    token = re.sub('[' + puntuaciones + ']+', '', token)
    token = re.split(r'[,]+', token)
    lista_tokens.append(token)
    
datos_preprocesados = lista_tokens
# Out:
# 48587

# %% [markdown]
# # Representación del texto mediante Doc2Vec

# %%
import numpy as np
from gensim.models.doc2vec import Doc2Vec, TaggedDocument


def texto_doc2vec(datos_preprocesados, épocas):
    datos_etiquetados = [TaggedDocument(words=_d, tags=[str(i)]) for i, _d in enumerate(datos_preprocesados)]
    
    #modelo de bolsa de palabras distribuida del vector de párrafo (PV-DBOW)
    modelo_doc2vec = Doc2Vec(vector_size = 100,
                    seed = 101,
                    window = 5,
                    epochs = épocas,
                    min_count = 5,
                    dm = 0,
                    dbow_words = 1)
    
    modelo_doc2vec.build_vocab(datos_etiquetados)
       
    for época in range(épocas):
        print('iteracción {0}'.format(época))
        
        modelo_doc2vec.train(datos_etiquetados,
                    total_examples = modelo_doc2vec.corpus_count,
                    epochs = modelo_doc2vec.epochs)
        
        modelo_doc2vec.min_alpha = modelo_doc2vec.alpha
    
    modelo_doc2vec.save("d2v2_{}.model".format(épocas))
    print("Modelo guardado") 
    
    return modelo_doc2vec

# %%
épocas = 10

modelo_doc2vec = texto_doc2vec(datos_preprocesados, épocas = épocas)
datos_doc2vec = np.array([modelo_doc2vec.dv[i] for i in range(len(datos_preprocesados))])

print(datos_doc2vec)
# Out:
# iteracción 0
# iteracción 1
# iteracción 2
# iteracción 3
# iteracción 4
# iteracción 5
# iteracción 6
# iteracción 7
# iteracción 8
# iteracción 9
# Modelo guardado
# [[-0.12909403  0.2566965  -0.11159543 ...  0.13863236  0.10544164
#    0.14491042]
#  [ 0.3722844   0.22971724  0.32077587 ...  0.30743998 -0.33395228
#    0.17261992]
#  [-0.19994284  0.7020714  -0.2087605  ... -0.52888256  1.3967148
#    0.7727729 ]
#  ...
#  [ 0.7339924   0.21822582  0.11907171 ... -0.5566083  -0.1626066
#   -0.03181605]
#  [ 0.00817005  0.4379914  -0.3424894  ...  0.09858466  0.28613633
#    0.30631962]
#  [ 0.45902434  0.30785748  0.3969614  ...  0.05142074  0.00283354
#    0.7743317 ]]

# %% [markdown]
# # Reducción de la dimensionalidad de los vectores de palabras para su visualización

# %%
import gensim
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

modelo = gensim.models.Doc2Vec.load('d2v2_10.model')

palabras = []
etiquetas_palabras = []

for palabra in modelo.wv.key_to_index:
    palabras.append(modelo.wv[palabra])
    etiquetas_palabras.append(palabra)
    
print('Añadidas %s palabras. Dimensión %s'%(len(palabras),np.shape(palabras)))

pca = PCA(n_components = 3)
pca.fit(palabras)
reducción = pca.transform(palabras)
 
for i, vec in enumerate(reducción):
    if i < 100:
        x,y = vec[0],vec[1]
        plt.scatter(x,y)
        plt.annotate(etiquetas_palabras[i],xy=(x,y))
        
plt.show()
# Out:
# Añadidas 8800 palabras. Dimensión (8800, 100)

# %% [markdown]
# # Visualización de los vectores de documentos (tweets)

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import random

plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

colores = ['blue','red','green','blue','cyan','yellow','orange','black','pink','brown','purple']

documentos = []

for i in range(48587):
    documentos.append(modelo.dv[i])

pca = PCA(n_components = 3)
pca.fit(documentos)
reducción = pca.transform(documentos)

asignar=[]
for i in range(48587):
    asignar.append(colores[random.randint(0, 10)])
    
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(reducción[:, 0], reducción[:, 1], reducción[:, 2], c = asignar,s = 30)
# Out:
# C:\Users\erick\AppData\Local\Temp/ipykernel_10784/2857508763.py:24: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# # Método del codo para saber el número óptimo de grupos

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import numpy as np
from gensim.models.doc2vec import Doc2Vec

def kmeans_cluster(datos_doc2vec):    
    distortions = []

    for i in range(1,15):
        km = KMeans(n_clusters = i, init = 'k-means++', n_init = 10 , max_iter = 300, random_state=0)
        km.fit(datos_doc2vec)
        distortions.append(km.inertia_)
        
    plt.plot(range(1,15), distortions, marker='o')
    plt.xlabel('Numero de clusters')
    plt.ylabel('Distorsión')
    plt.show()
    
kmeans_cluster(datos_doc2vec)

# %% [markdown]
# # Método de la silueta para saber el número óptimo de grupos

# %%
número_clusters = range(2,41)

lista_inercia = []
lista_umbral = []
lista_kmn = []

for k in número_clusters:
    kmn = KMeans(n_clusters = k, random_state = 2020, max_iter = 100)
    kmn.fit(datos_doc2vec)
    etiquetas = kmn.predict(datos_doc2vec)
    lista_inercia.append(kmn.inertia_)
    lista_umbral.append(silhouette_score(datos_doc2vec, etiquetas))
    lista_kmn.append(kmn)
    print('número de cluster: ', k)

# %%
plt.plot(range(1, len(lista_inercia) + 1), [i / 1000 for i in lista_inercia], marker= 'o', linestyle='-')
plt.ylim(60,75)
plt.xlim(0,20)    
plt.axvline(6, 0, 90, linestyle='--', c='red')
plt.xlabel("Número de clusters", fontsize=16)
plt.ylabel('Inertia(×1000)', fontsize=16)
plt.xticks(np.arange(0, 22, step=2))
plt.yticks(np.arange(60, 80, step=5))   
plt.figure()
plt.plot(range(1, len(lista_umbral)+1), lista_umbral, marker= 'o', linestyle='-')

# %% [markdown]
# # Aplicación del algoritmo K-Means

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import gensim
from sklearn import metrics
from sklearn.metrics import pairwise_distances

def kmeans_cluster(datos_doc2vec, número_clusters):
    kmn = KMeans(n_clusters = número_clusters, random_state = 1010, max_iter=100)
    kmn.fit(datos_doc2vec)
    labels = kmn.labels_
    
    #print(metrics.silhouette_score(datos_doc2vec, labels, metric='euclidean'))
    sample_silhouette_values = metrics.silhouette_samples(datos_doc2vec, labels)

    means_lst = []
    for label in range(número_clusters):
        means_lst.append(sample_silhouette_values[labels == label].mean())
    
    print(means_lst)
    
    etiquetas = kmn.predict(datos_doc2vec)

    return kmn, etiquetas

modelo = gensim.models.Doc2Vec.load('d2v2_10.model')
datos_doc2vec = np.array([modelo.dv[i] for i in range(48587)])

número_clusters = 6
kmn, etiquetas = kmeans_cluster(datos_doc2vec, número_clusters)
   
cluster = []
list_lat = []
list_long = []

for n in range(número_clusters):
    cluster.append([datos_preprocesados[i] for i, e in enumerate(etiquetas) if e == n])
    list_lat.append([latitudes[i] for i, e in enumerate(etiquetas) if e == n])
    list_long.append([longitudes[i] for i, e in enumerate(etiquetas) if e == n])
# Out:
# [-0.12137417, -0.12655418, -0.1263563, -0.092147455, 0.18501015, -0.10481504]

# %%
coord = entrenamiento['coordinates']

latitudes = []
longitudes = []

size = len(coord)

for i in range(size):
    if type(coord[i]) is str:
        #print(coord[i])
        dicc = eval(coord[i])
        latitudes.append(dicc['latitude'])
        longitudes.append(dicc['longitude'])
    else:
        latitudes.append("")
        longitudes.append("")
        print('hey')

# %%
número_clusters = 6

for i in range(número_clusters):
    lista_c = []
    lista_lat = []
    lista_lon = [] 
    
    for tweet in cluster[i]:
        lista_c.append(tweet)

    for tweet in list_long[i]:
        lista_lon.append(tweet)

    for tweet in list_lat[i]:
        lista_lat.append(tweet)

    l = []
    t = ""
    for tweet in lista_c:
        for s in tweet:
            s = s.strip()
            t += s
            t += " "
    
        l.append(t)
        t=""

    dfa = pd.DataFrame(l)
    dfa.columns = ['cluster']
    dfa['lat'] = lista_lat
    dfa['lon'] = lista_lon
    dfa.to_csv('clusterN-{}.csv'.format(i),index=False)

# %%
dfa.head()
# Out:
#                                              cluster        lat        lon
# 0            vacuna medico exigimos vacuna hospital   19.366862 -99.067766
# 1  pinche medico pendejo aparte revoltoso exigir ...  19.087511 -99.315748
# 2  joven estudiante derecho vacuna exigimos agili...  19.404352 -99.128294
# 3  ano prometer sistema salud tipo dinamarca desa...  19.357102 -99.191996
# 4  gusto menor recuperar saber hospital acudir pr...  19.087511 -99.315748

# %%
import gensim
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

clusters = kmn.predict(datos_doc2vec[:240])
centroides = kmn.cluster_centers_

documentos = []
centroides_pca = []

for i in range(len(clusters)):
    documentos.append(modelo.dv[i])
    
pca = PCA(n_components = 2)
pca.fit(documentos)
reducción = pca.transform(documentos)

for i in range(len(centroides)):
    centroides_pca.append(centroides[i])
    
pca = PCA(n_components = 3)
pca.fit(documentos)
reducción_centroides = pca.transform(centroides_pca)

colores = ['red','green','blue','cyan','yellow', 'purple']
asignar = []

for c in clusters:
    asignar.append(colores[c])

#fig = plt.figure()
#ax = Axes3D(fig)

#ax.scatter(reducción[:, 0], reducción[:, 1], c = asignar,s = 60)
#ax.scatter(reducción_centroides[:, 0], reducción_centroides[:, 1], marker='*', c=colores, s=1000)
plt.scatter(reducción[:, 0], reducción[:, 1], c=asignar, s=70)
plt.scatter(reducción_centroides[:, 0], reducción_centroides[:, 1], marker='*', c=colores, s=1000)
plt.show()

# %% [markdown]
# # Guarda los clusters encontrados en formato csv

# %%
import csv  

número_clusters = 6

for i in range(número_clusters):
    archivo = 'cluster-{}.csv'.format(i)
    
    with open(archivo, 'w', newline='', encoding = 'utf-8') as objeto_archivo:
        obj = csv.writer(objeto_archivo, dialect='excel')
        
        for tweet in cluster[i]:
            obj.writerow(tweet)

# %% [markdown]
# # Lectura de los clusters

# %%
documento = open('cluster-5.csv','r').read().splitlines()
#print(documento)

lista_doc = []

for d in documento:
    lista_doc.append(d.replace(" ", "").split(','))
    
#print(lista_doc)

# %%
import pandas as pd
nombre_archivo = "clusterN-5.csv"

df_tw = pd.read_csv(nombre_archivo)
df_tw.head()
# Out:
#                                              cluster        lat        lon
# 0  ridiculo adelantar comprar vacuna decir papa r...  19.399835 -99.184350
# 1  mama reaccion aplicacion vacuna cansancio dolo...  19.498594 -99.248181
# 2                                 vacuna ching ando   19.399835 -99.184350
# 3  seguir adolorido fiebre quitar pasar esperar d...  19.456367 -99.221136
# 4   dio reaccion vacuna astrazeneca sentir reaccion   19.357102 -99.191996

# %%
lista_doc = df_tw['cluster'].tolist()

# %%
lista_documentos = []

for d in lista_doc:
    lista_documentos.append(d.rstrip().split(' '))
    
#print(lista_documentos)

# %%
def generar_bigramas(tweet_tokenizado):
    i = 0
    
    tamañio = len(tweet_tokenizado)
    palabras = tweet_tokenizado
    
    for palabra in palabras:
        if palabra == 'dolor':
            if not (i + 1 == tamañio):
               
                if palabras[i + 1] == 'pierna':
                    palabras[i] = 'dolor pierna'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'brazo':
                    
                    palabras[i] = 'dolor brazo'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'cabeza':
                    palabras[i] = 'dolor cabeza'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'muscular':
                    palabras[i] = 'dolor muscular'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'articular':
                    palabras[i] = 'dolor articular'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'cuerpo':
                    palabras[i] = 'dolor cuerpo'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                elif palabras[i + 1] == 'garganta':
                    palabras[i] = 'dolor garganta'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                    
        if palabra == 'dificultad':
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'respirar':
                    palabras[i] = 'dificultad respirar'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                    
        if palabra == 'cuerpo':
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'cortado':
                    palabras[i] = 'cuerpo cortado'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                    
        if palabra == 'irritacion':
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'brazo':
                    palabras[i] = 'irritacion brazo'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1] 
        
        if palabra == 'inflamacion':
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'brazo':
                    palabras[i] = 'inflamacion brazo'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
        
        if palabra == 'hinchazon':
            if not (i + 1 == tamañio):
                if palabras[i + 1] == 'brazo':
                    palabras[i] = 'hinchazon brazo'
                    
                    tamañio = tamañio - 1
                    del palabras[i + 1]
                        
        i += 1
        
    return palabras

lis = []
for l in lista_documentos:
    lis.append(generar_bigramas(l))
    
print(lis)

# %%
lista_documentos = lis

# %% [markdown]
# # Diagrama nube de palabras para un cluster

# %%
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt

archivo = pd.read_csv("cluster-4.csv", encoding = "ISO-8859-1", sep='\t', header=None)

cluster = archivo[0]

tweets = " "

for c in cluster:
    tweets = tweets + c.replace(","," ")
    
nube_palabras = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(tweets)
                        
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(nube_palabras)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
from nltk.corpus import stopwords

def remover_stopwords(tweet_tokenizado):   
    with open('stopwords.txt', encoding='utf-8') as f:
        palabras_auxiliares = f.read().splitlines()
        
    stop_words = stopwords.words('spanish')
    
    for palabra in palabras_auxiliares:
        stop_words.append(palabra)
    
    lista = []
    
    for palabras in tweet_tokenizado:
        lpalabras = []
        for palabra in palabras:
            if palabra not in stop_words:
                lpalabras.append(palabra)
        lista.append(lpalabras)
    tweet_tokenizado = lista#[palabra for palabra in tweet_tokenizado if palabra not in stop_words]
    
    return tweet_tokenizado

list_doc = remover_stopwords(lista_documentos)

# %%
from gensim import corpora

# create dictionary
dictionary = corpora.Dictionary(list_doc)
dictionary.filter_extremes(no_below = 20, no_above=0.5)
#del_ids = [k for k,v in dictionary.items() if v=='dosis']
#dictionary.filter_tokens(bad_ids=del_ids)

# create document term matrix
bow = [dictionary.doc2bow(text) for text in list_doc]

# %%
from gensim.models import LdaModel
from gensim.models.coherencemodel import CoherenceModel
import numpy as np 

best_num = float('NaN')
best_score = 0

# compute the coherence scores for each number of topics
for i in range(2,11):
    
    # create lda model with i topics
    lda = LdaModel(corpus=bow, num_topics=i, id2word=dictionary, random_state=42)
    
    # obtain the coherence score
    coherence_model = CoherenceModel(model=lda, texts=list_doc, dictionary=dictionary, coherence='c_v')
    coherence_score = np.round(coherence_model.get_coherence(),2)
    if coherence_score > best_score:
        best_num = i
        best_score = coherence_score

print(f'The coherence score is highest ({best_score}) with {best_num} topics.')
# Out:
# The coherence score is highest (0.32) with 10 topics.

# %%
import gensim
lda_model = gensim.models.ldamodel.LdaModel(corpus=bow,
                                           id2word=dictionary,
                                           num_topics=10, 
                                           random_state=42)

# %%
for topic in lda_model.print_topics(num_words=50):
    print(topic)
# Out:
# (0, '0.100*"cansancio" + 0.024*"dosis" + 0.023*"registrar" + 0.021*"empezar" + 0.017*"feo" + 0.017*"ano" + 0.016*"vida" + 0.016*"mama" + 0.015*"abrazo" + 0.014*"animo" + 0.013*"esterilizado" + 0.013*"obvio" + 0.013*"miercoles" + 0.012*"llamar" + 0.012*"viaje" + 0.011*"semana" + 0.011*"problema" + 0.011*"seguro" + 0.010*"cara" + 0.010*"salir" + 0.010*"covid" + 0.010*"pagina" + 0.010*"pinche" + 0.009*"paso" + 0.009*"auto" + 0.009*"recibir" + 0.009*"viejo" + 0.009*"meter" + 0.009*"amigo" + 0.009*"saludo" + 0.008*"mexico" + 0.008*"venir" + 0.008*"ahorita" + 0.008*"salud" + 0.008*"repetir" + 0.008*"nivel" + 0.007*"gracias" + 0.007*"comenzar" + 0.007*"olvidar" + 0.007*"fuerte" + 0.007*"aplicar" + 0.007*"mental" + 0.007*"campana" + 0.006*"volver" + 0.006*"justo" + 0.006*"tema" + 0.006*"mes" + 0.006*"recuperar" + 0.006*"andar" + 0.006*"cita"')
# (1, '0.040*"esperar" + 0.038*"llegar" + 0.032*"sputnik" + 0.031*"jajaja" + 0.031*"dosis" + 0.030*"manana" + 0.024*"ruso" + 0.023*"amigo" + 0.021*"seguir" + 0.019*"puse" + 0.018*"pensar" + 0.017*"influenza" + 0.017*"pasar" + 0.016*"ando" + 0.016*"jajajajaja" + 0.016*"pinche" + 0.016*"toque" + 0.013*"derecho" + 0.013*"amar" + 0.012*"saludo" + 0.011*"gusto" + 0.011*"tocar" + 0.011*"juego" + 0.010*"faltar" + 0.010*"confirmar" + 0.010*"sacar" + 0.009*"reaccion" + 0.009*"emocionado" + 0.009*"sintoma" + 0.009*"mame" + 0.008*"hablar" + 0.008*"alcohol" + 0.008*"noche" + 0.008*"sa" + 0.008*"covid" + 0.008*"quedar" + 0.008*"aplicar" + 0.008*"pfizer" + 0.008*"perder" + 0.007*"refuerzo" + 0.007*"ay" + 0.007*"cabeza" + 0.007*"camino" + 0.007*"preguntar" + 0.007*"doler" + 0.007*"cita" + 0.007*"leer" + 0.007*"paz" + 0.006*"jajajaja" + 0.006*"recibir"')
# (2, '0.055*"gente" + 0.021*"alguien" + 0.021*"senor" + 0.021*"perro" + 0.020*"foto" + 0.018*"pinche" + 0.017*"excelente" + 0.017*"agua" + 0.017*"red" + 0.016*"efecto" + 0.015*"organizacion" + 0.015*"sputnik" + 0.015*"moderna" + 0.015*"loco" + 0.013*"dosis" + 0.013*"pasar" + 0.013*"gustar" + 0.013*"subir" + 0.012*"pedir" + 0.012*"lunes" + 0.011*"centro" + 0.011*"problema" + 0.011*"lograr" + 0.010*"inicio" + 0.010*"lleno" + 0.010*"super" + 0.009*"punto" + 0.009*"semana" + 0.009*"ridiculo" + 0.009*"cosa" + 0.009*"miedo" + 0.009*"inyectar" + 0.008*"escuchar" + 0.008*"esperar" + 0.008*"generacion" + 0.008*"pagar" + 0.008*"pensar" + 0.008*"idea" + 0.008*"seguir" + 0.007*"sacar" + 0.007*"alegria" + 0.007*"hora" + 0.007*"esperanza" + 0.007*"queja" + 0.007*"falta" + 0.007*"seguro" + 0.006*"baja" + 0.006*"llamar" + 0.006*"gobierno" + 0.006*"pequeno"')
# (3, '0.040*"dosis" + 0.039*"salir" + 0.038*"papas" + 0.027*"covid" + 0.023*"esperar" + 0.022*"acabar" + 0.021*"feliz" + 0.019*"papa" + 0.019*"caer" + 0.019*"encontrar" + 0.019*"seguir" + 0.016*"preguntar" + 0.016*"gracias" + 0.014*"recibir" + 0.014*"pensar" + 0.013*"noticia" + 0.013*"puesto" + 0.013*"mama" + 0.013*"pedo" + 0.012*"dios" + 0.012*"deseo" + 0.012*"malo" + 0.011*"viejitos" + 0.011*"emocion" + 0.011*"xd" + 0.010*"pasar" + 0.010*"pandemia" + 0.010*"foto" + 0.009*"sintoma" + 0.009*"cuidando" + 0.009*"contento" + 0.009*"contagiar" + 0.009*"neta" + 0.009*"boca" + 0.008*"quitar" + 0.008*"sentir" + 0.008*"negativo" + 0.008*"abuelo" + 0.008*"felicidad" + 0.008*"agradecido" + 0.008*"urge" + 0.007*"molestia" + 0.007*"semana" + 0.007*"mame" + 0.007*"casa" + 0.007*"importante" + 0.007*"video" + 0.007*"astrazeneca" + 0.007*"doctor" + 0.007*"registrado"')
# (4, '0.056*"cansancio" + 0.041*"covid" + 0.033*"dosis" + 0.021*"feliz" + 0.020*"viernes" + 0.019*"tocar" + 0.017*"sentir" + 0.017*"registro" + 0.017*"domingo" + 0.017*"dolor cabeza" + 0.017*"sueno" + 0.015*"dolor" + 0.014*"andar" + 0.013*"ojo" + 0.013*"abrir" + 0.013*"esperar" + 0.012*"amiga" + 0.012*"astrazeneca" + 0.012*"empezar" + 0.012*"real" + 0.012*"sputnik" + 0.011*"pedir" + 0.010*"cantar" + 0.010*"cuerpo" + 0.010*"fiesta" + 0.010*"ayudar" + 0.010*"hambre" + 0.010*"banda" + 0.009*"morir" + 0.009*"puro" + 0.009*"justo" + 0.008*"seguir" + 0.008*"salir" + 0.008*"tos" + 0.007*"extremo" + 0.007*"semana" + 0.007*"palacio" + 0.007*"vivir" + 0.007*"cortar" + 0.007*"manana" + 0.007*"ano" + 0.006*"recuperacion" + 0.006*"doler" + 0.006*"deporte" + 0.006*"dolor brazo" + 0.006*"ansiedad" + 0.006*"garganta" + 0.006*"increible" + 0.006*"fiebre" + 0.005*"levantar"')
# (5, '0.122*"dosis" + 0.023*"esperar" + 0.021*"creer" + 0.019*"vida" + 0.016*"ano" + 0.015*"falta" + 0.014*"hija" + 0.014*"mama" + 0.014*"acompanar" + 0.014*"llegar" + 0.013*"tocar" + 0.013*"abuelito" + 0.012*"comprobante" + 0.012*"papa" + 0.011*"familia" + 0.011*"comer" + 0.011*"ganar" + 0.011*"historia" + 0.010*"felicidad" + 0.010*"casa" + 0.010*"querido" + 0.009*"acabar" + 0.009*"semana" + 0.009*"manana" + 0.009*"leer" + 0.009*"vivir" + 0.009*"cuidado" + 0.009*"mujer" + 0.008*"cansancio" + 0.008*"entrar" + 0.008*"sentir" + 0.008*"pasar" + 0.008*"feliz" + 0.008*"guardia" + 0.008*"bajar" + 0.008*"paso" + 0.007*"salir" + 0.007*"gustar" + 0.007*"santo" + 0.007*"taco" + 0.007*"completo" + 0.007*"centro" + 0.007*"libro" + 0.007*"terminar" + 0.007*"abuelita" + 0.007*"mamen" + 0.007*"seguir" + 0.006*"buscar" + 0.006*"perder" + 0.006*"dolor"')
# (6, '0.030*"moderna" + 0.028*"post" + 0.022*"cansancio" + 0.020*"fila" + 0.020*"bonito" + 0.019*"minuto" + 0.019*"dosis" + 0.018*"ojala" + 0.017*"unico" + 0.017*"fiebre" + 0.016*"gracias" + 0.015*"covid" + 0.014*"pasen" + 0.014*"falta" + 0.013*"don" + 0.013*"nomas" + 0.012*"presidente" + 0.011*"dolor brazo" + 0.011*"pendejo" + 0.011*"cafe" + 0.011*"doler" + 0.011*"astrazeneca" + 0.011*"doctora" + 0.010*"semana" + 0.010*"pregunta" + 0.010*"noche" + 0.009*"esperar" + 0.009*"vengo" + 0.009*"experiencia" + 0.009*"hablar" + 0.009*"robar" + 0.009*"quitar" + 0.008*"respeto" + 0.008*"janssen" + 0.008*"preocupar" + 0.008*"enfermedad" + 0.008*"mes" + 0.007*"anti" + 0.007*"energia" + 0.007*"puse" + 0.007*"deber" + 0.007*"sentir" + 0.007*"mirar" + 0.007*"dolor muscular" + 0.007*"hora" + 0.006*"regresar" + 0.006*"maldito" + 0.006*"partido" + 0.006*"senor" + 0.006*"aire"')
# (7, '0.072*"dosis" + 0.048*"sentir" + 0.028*"persona" + 0.024*"tocar" + 0.020*"mama" + 0.020*"gente" + 0.020*"duda" + 0.019*"papa" + 0.017*"cansancio" + 0.017*"jaja" + 0.016*"formar" + 0.016*"recibir" + 0.015*"pena" + 0.014*"normal" + 0.013*"sputnik" + 0.013*"verga" + 0.013*"disfrutar" + 0.013*"pensar" + 0.013*"manana" + 0.012*"necesitar" + 0.012*"tranquilo" + 0.012*"venir" + 0.011*"jueves" + 0.011*"rapido" + 0.011*"covid" + 0.011*"fila" + 0.010*"valer" + 0.009*"ayuda" + 0.009*"formado" + 0.009*"esperar" + 0.009*"cero" + 0.009*"madre" + 0.009*"cambiar" + 0.009*"zona" + 0.008*"medicamento" + 0.008*"ano" + 0.008*"tranquilidad" + 0.008*"mierda" + 0.007*"medico" + 0.007*"pendiente" + 0.007*"ojala" + 0.007*"tipo" + 0.007*"minuto" + 0.007*"hermana" + 0.007*"acabar" + 0.006*"alto" + 0.006*"astrazeneca" + 0.006*"volver" + 0.006*"mundo" + 0.006*"miedo"')
# (8, '0.044*"pasar" + 0.044*"reaccion" + 0.041*"dosis" + 0.028*"padre" + 0.028*"super" + 0.024*"dormir" + 0.018*"noche" + 0.018*"nino" + 0.017*"mediodia" + 0.016*"gracias" + 0.015*"hermoso" + 0.015*"cansancio" + 0.014*"madre" + 0.014*"mes" + 0.014*"vacunada" + 0.013*"doctor" + 0.012*"ah" + 0.012*"sentir" + 0.012*"covid" + 0.011*"listo" + 0.011*"corazon" + 0.011*"persona" + 0.010*"toque" + 0.009*"mil" + 0.009*"volver" + 0.009*"feliz" + 0.009*"maestro" + 0.008*"problema" + 0.008*"cuerpo" + 0.008*"amor" + 0.008*"abierto" + 0.008*"virus" + 0.008*"recibir" + 0.008*"leve" + 0.008*"sueno" + 0.007*"cabron" + 0.007*"dato" + 0.007*"jeringa" + 0.007*"tia" + 0.006*"hola" + 0.006*"registre" + 0.006*"respuesta" + 0.006*"azul" + 0.006*"deber" + 0.006*"mama" + 0.006*"esperar" + 0.006*"dios" + 0.006*"rey" + 0.006*"afortunadamente" + 0.005*"amiga"')
# (9, '0.036*"casa" + 0.035*"mama" + 0.034*"tocar" + 0.028*"hijo" + 0.025*"madre" + 0.019*"hermano" + 0.017*"mexico" + 0.017*"venir" + 0.017*"ano" + 0.017*"llorar" + 0.017*"oigan" + 0.015*"salir" + 0.015*"cuidar" + 0.014*"gana" + 0.013*"preferir" + 0.013*"cansancio" + 0.012*"brazo" + 0.012*"servir" + 0.012*"hermana" + 0.012*"mano" + 0.011*"pobre" + 0.011*"familiar" + 0.011*"sputnik" + 0.010*"papa" + 0.010*"muerto" + 0.010*"quedar" + 0.009*"llegar" + 0.009*"miedo" + 0.009*"padre" + 0.009*"menor" + 0.009*"familia" + 0.009*"puta" + 0.008*"esfuerzo" + 0.008*"grande" + 0.008*"cansado" + 0.008*"quedate" + 0.008*"funcionar" + 0.007*"toma" + 0.007*"bello" + 0.007*"sentir" + 0.007*"amigo" + 0.007*"cielo" + 0.007*"mes" + 0.007*"amor" + 0.007*"formar" + 0.007*"adulto" + 0.007*"prepa" + 0.007*"creer" + 0.006*"favor" + 0.006*"turno"')

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def create_wordcloud(model, topic):
    text = {word: value for word, value in model.show_topic(topic,60)}
    wc = WordCloud(background_color="white", max_words=1000)
    wc.generate_from_frequencies(text)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title("Topic" + " "+ str(topic))
    plt.show()

for i in range(0,10):
    create_wordcloud(lda_model, topic=i)

# %%
topic_dist = lda_model[bow]

# store distributions ina list
dist = []
for t in topic_dist:
    dist.append(t)

print(topic_dist[2653])
# Out:
# [(0, 0.014287582), (1, 0.014288355), (2, 0.2230088), (3, 0.13992544), (4, 0.0142899), (5, 0.22263639), (6, 0.014289563), (7, 0.014289761), (8, 0.014288041), (9, 0.32869613)]

# %%
import pandas as pd

def format_topics_sentences(ldamodel, corpus, text, lat, lon):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
    
    contents = pd.Series(text)
    sent_topics_df = pd.concat([sent_topics_df, contents, lat, lon], axis=1)
    return(sent_topics_df)
    

lat = df_tw['lat']
lon = df_tw['lon']

df_topic_sents_keywords = format_topics_sentences(lda_model, bow, list_doc,lat,lon)

# %%
df_topic_sents_keywords.loc[2653]
# Out:
# Dominant_Topic                                                     3.0
# Perc_Contribution                                               0.6213
# Topic_Keywords       salir, dosis, papas, covid, acabar, esperar, f...
# 0                    [efecto, vacuna, tos, dolorgarganta, anoche, s...
# Name: 2653, dtype: object

# %%
dtn = df_topic_sents_keywords.loc[(df_topic_sents_keywords['Dominant_Topic'] == 9.0)]

# %%
dtn.to_csv('posibles_efectos10.csv')

# %%
import numpy as np
a = lda_model.state.get_lambda()
print(np.apply_along_axis(lambda x: x/x.sum(),1,a))
# Out:
# [[5.9068215e-04 1.2658531e-03 1.2559551e-03 ... 2.3214654e-05
#   2.3215116e-05 1.4938546e-03]
#  [2.9024719e-05 1.0215663e-04 2.9029345e-05 ... 2.9018469e-05
#   2.9016042e-05 2.9185785e-05]
#  [1.1226381e-03 1.6561073e-04 8.8646347e-03 ... 2.4591944e-05
#   2.4587587e-05 2.4582645e-05]
#  ...
#  [2.8380478e-05 1.8717492e-02 2.8422584e-05 ... 2.8383754e-05
#   2.8380144e-05 2.8504379e-05]
#  [7.5208904e-05 2.6072399e-05 5.3661887e-04 ... 2.6057305e-05
#   2.6055384e-05 2.6135849e-05]
#  [2.7789665e-05 1.0588962e-02 1.0341355e-04 ... 6.8511800e-03
#   2.7784023e-05 3.2817348e-05]]
